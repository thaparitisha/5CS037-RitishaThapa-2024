# %% [markdown]
# # **3.1 Problem - 1: Getting Started with Data Exploration - Some Warm up Exercises:**

# %% [markdown]
# ## 1. Data Exploration and Understanding:
#
# • Dataset Overview:
# 1. Load the dataset and display the first 10 rows.
# 2. Identify the number of rows and columns in the dataset.
# 3. List all the columns and their data types.

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('/content/drive/MyDrive/AI Assignment/WHR-2024-5CS037.csv')

# Display the first 10 rows
df.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %%
#identify the number of rows and columns in the dataset.
rows, cols = df.shape
print(f"Number of rows: {rows}, Number of columns: {cols}")
# Out:
# Number of rows: 143, Number of columns: 9

# %%
#list all the columns and their data types.
print(df.dtypes)
# Out:
# Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %%
#displaying the columns in dataset to check the name of them in list
print("Columns in the dataset:", df.columns.tolist())
# Out:
# Columns in the dataset: ['Country name', 'score', 'Log GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption', 'Dystopia + residual']

# %% [markdown]
# **• Basic Statistics:**
#
# Calculate the mean, median, and standard deviation for the Score column.
# Identify the country with the highest and lowest happiness scores.
#
# ```
# # This is formatted as code
# ```

# %%
#Calculate the mean, median, and standard deviation for the Score column.
mean_score = df['score'].mean()
median_score = df['score'].median()
std_dev_score = df['score'].std()

print(f"Mean Score: {mean_score:.2f}, Median Score: {median_score:.2f}, Standard Deviation: {std_dev_score:.2f}")
# Out:
# Mean Score: 5.53, Median Score: 5.79, Standard Deviation: 1.17

# %%
#Identify the country with the highest and lowest happiness scores.
highest_happiness = df.loc[df['score'].idxmax(), 'Country name']
lowest_happiness = df.loc[df['score'].idxmin(), 'Country name']

print(f"Highest Happiness Score Country: {highest_happiness}")
print(f"Lowest Happiness Score Country: {lowest_happiness}")
# Out:
# Highest Happiness Score Country: Finland
# Lowest Happiness Score Country: Afghanistan

# %% [markdown]
# **• Missing Values:**
#
# Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
# Check for missing values and display them
missing_values = df.isnull().sum()
print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# **• Filtering and Sorting:**
#
# Filter the dataset to show only the countries with a Score greater than 7.5.
#
# For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the top 10 rows.

# %%
#Filter the dataset to show only the countries with a Score greater than 7.5.
filtered_df = df[df['score'] > 7.5]
filtered_df
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
#
#    Perceptions of corruption  Dystopia + residual
# 0                      0.546                2.082
# 1                      0.548                1.881
# 2                      0.182                2.050

# %%
#Sort the filtered dataset by GDP per Capita in descending order
sorted_df = filtered_df.sort_values(by='Log GDP per capita', ascending=False)

#Display the top 10 rows
sorted_df.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 0      Finland  7.741               1.844           1.572
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 0                    0.695                         0.859       0.142
#
#    Perceptions of corruption  Dystopia + residual
# 1                      0.548                1.881
# 2                      0.182                2.050
# 0                      0.546                2.082

# %% [markdown]
# **• Adding New Columns:**
#
# Create a new column called Happiness Category that categorizes countries into three categories based on their Score:
#
# Low − (Score < 4) Medium − (4 ≤ Score ≤ 6) High − (Score > 6)

# %%
#Create a new column called Happiness Category based on the Score.
def categorize_happiness(score):
    if score < 4:
        return 'Low'
    elif 4 <= score <= 6:
        return 'Medium'
    else:
        return 'High'

df['Happiness Category'] = df['score'].apply(categorize_happiness)
print(df[['Country name', 'score', 'Happiness Category']].head(10))
# Out:
#   Country name  score Happiness Category
# 0      Finland  7.741               High
# 1      Denmark  7.583               High
# 2      Iceland  7.525               High
# 3       Sweden  7.344               High
# 4       Israel  7.341               High
# 5  Netherlands  7.319               High
# 6       Norway  7.302               High
# 7   Luxembourg  7.122               High
# 8  Switzerland  7.060               High
# 9    Australia  7.057               High

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Sort dataset by Score in descending order and select the top 10 happiest countries
top10_happiest = df.sort_values(by='score', ascending=False).head(10)

# Plot the bar chart
plt.figure(figsize=(12, 6))
sns.barplot(x='Country name', y='score', hue='score',data =top10_happiest, palette  ='magma', legend=False)
plt.title('Top 10 Happiest Countries by Score', fontsize=16)
plt.ylabel('Happiness Score', fontsize=12)
plt.xlabel('Country', fontsize=12)
plt.show()

# %%
# Sort dataset by Score in ascending order and select the top 10 unhappiest countries
top10_unhappiest = df.sort_values(by='score', ascending=True).head(10)

# Plot the line chart
plt.figure(figsize=(10, 5))
plt.plot(top10_unhappiest['Country name'],top10_unhappiest['score'], marker='o', color='red')
plt.title('Top 10 Unhappiest Countries by Score', fontsize=16)
plt.xlabel('Happiness Score', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(rotation=45)

plt.show()

# %%
# Plot the histogram for the Score column
plt.figure(figsize=(10, 6))
sns.histplot(df['score'], color='seagreen', bins = 20, kde=True,edgecolor='black')
plt.title('Distribution of Happiness Scores', fontsize=16)
plt.xlabel('Happiness Score', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

plt.show()

# %%
# Scatter plot between GDP per Capita and Score
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Log GDP per capita', y='score', data=df, color='yellow', alpha=0.7, edgecolor='black', legend= False)

# Add titles and labels
plt.title('Relationship between GDP per Capita and Happiness Score', fontsize=16)
plt.xlabel('GDP per Capita', fontsize=12)
plt.ylabel('Happiness Score', fontsize=12)
plt.show()

# %% [markdown]
# # **3.2 Problem - 2 - Some Advance Data Exploration Task:**
#
# Task - 1 - Setup Task - Preparing the South-Asia Dataset:
# Steps:
# 1. Define the countries in South Asia with a list for example:
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
# "Maldives", "Nepal", "Pakistan", "Srilanka"]
#
# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
#
# 3. Save the filtered dataframe as separate CSV files for future use.

# %%
#Defining south asian countries
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India","Maldives", "Nepal", "Pakistan", "Sri Lanka"]

southAsia_df = df[df['Country name'].isin(south_asian_countries)]

# Save the filtered dataset to a new CSV file
southAsia_df.to_csv('south_asia_happiness_scores.csv', index=False)

southAsia_df.head()
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
#
#      Perceptions of corruption  Dystopia + residual Happiness Category
# 92                       0.115                1.783             Medium
# ...

# %% [markdown]
# ## **Task - 2 - Composite Score Ranking:**
#
# Tasks:
#
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
#
# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support
# + 0.30 × Healthy Life Expectancy
# 2. Rank the South Asian countries based on the Composite Score in descending order.
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your
# discussion with some visualization plot.

# %%
#Load the new csv
southAsia_df= pd.read_csv('/content/south_asia_happiness_scores.csv')
# print(southAsia_df.head())
southAsia_df
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 3    Sri Lanka  3.898               1.361           1.179
# 4   Bangladesh  3.886               1.122           0.249
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
# 5                    0.242                         0.000       0.091
#
#    Perceptions of corruption  Dystopia + residual Happiness Category
# ...

# %%
#Create a new column called 'Composite Score'
southAsia_df['Composite Score'] = (southAsia_df['Log GDP per capita']*0.40 + southAsia_df['Social support']*0.30+0.30* southAsia_df['Healthy life expectancy'])
#print the column
southAsia_df
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 3    Sri Lanka  3.898               1.361           1.179
# 4   Bangladesh  3.886               1.122           0.249
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
# 5                    0.242                         0.000       0.091
#
# ...

# %%
#Rank Countries Based on Composite Score
sorted_southAsia_df = southAsia_df.sort_values(by='Composite Score', ascending=False)

print("Ranked South Asian Countries based on Composite Score:")
sorted_southAsia_df
# Out:
# Ranked South Asian Countries based on Composite Score:
#   Country name  score  Log GDP per capita  Social support  \
# 3    Sri Lanka  3.898               1.361           1.179
# 0        Nepal  5.158               0.965           0.990
# 2        India  4.054               1.166           0.653
# 1     Pakistan  4.657               1.069           0.600
# 4   Bangladesh  3.886               1.122           0.249
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 3                    0.586                         0.583       0.144
# 0                    0.443                         0.653       0.209
# 2                    0.417                         0.767       0.174
# 1                    0.321                         0.542       0.144
# 4                    0.513                         0.775       0.140
# 5                    0.242                         0.000       0.091
#
# ...

# %%
#Visualize the top 5 countries using a horizontal bar chart showing the Composite Score

top_5_countries = sorted_southAsia_df.head(5)

plt.figure(figsize=(10, 6))
sns.barplot( x='Composite Score', y='Country name', data=top_5_countries, palette='Blues_d', hue= 'score', legend= False)
plt.title('Top 5 South Asian Countries by Composite Score')
plt.xlabel('Composite Score')
plt.ylabel('Country')
plt.show()

# %%
top_5_countries_melted = pd.melt(top_5_countries, id_vars=['Country name'],
                                  value_vars=['Composite Score', 'score'],
                                  var_name='Score Type', value_name='Score Value')

# Plotting with Seaborn's barplot
plt.figure(figsize=(10, 6))
sns.barplot(x='Country name', y='Score Value', hue='Score Type',palette= "deep", data=top_5_countries_melted)

# Adding labels and title
plt.title('Comparison of Composite Score and Original Score for Top 5 Countries', fontsize=16)
plt.xlabel('Country Name', fontsize=12)
plt.ylabel('Score Value', fontsize=12)


# Show the plot
plt.show()

# %% [markdown]
# ## Task - 3 - Outlier Detection:
#
#
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
# 2. Define outliers using the 1.5 × IQR rule.
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %%
# Define IQR for 'GDP per Capita' and 'Score'
def detect_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] < lower_bound) | (df[column] > upper_bound)]


outliers_gdp = detect_outliers(southAsia_df, 'Log GDP per capita')
outliers_score = detect_outliers(southAsia_df, 'score')

# Combine outliers into a single DataFrame (avoiding duplicates)
southAsia_outliers = pd.concat([outliers_gdp, outliers_score]).drop_duplicates()

# Print the outlier countries
print("Outlier Countries based on GDP per Capita and Score:")
southAsia_outliers[['Country name', 'Log GDP per capita', 'score']]
# Out:
# Outlier Countries based on GDP per Capita and Score:
#   Country name  Log GDP per capita  score
# 5  Afghanistan               0.628  1.721

# %%
# Step 3: Scatter Plot Highlighting Outliers
plt.figure(figsize=(12, 7))

# Plot all countries
sns.scatterplot(data=southAsia_df, x='Log GDP per capita', y='score', color='gray', s=100, label='Non-Outliers')

# Highlight outliers
sns.scatterplot(data=southAsia_outliers, x='Log GDP per capita', y='score', color='red', s=100, label='Outliers')

plt.title('Outlier Detection: GDP per Capita vs Score')
plt.xlabel('GDP per Capita')
plt.ylabel('Score')
# plt.legend()
plt.show()

# %% [markdown]
# ## Task - 4 - Exploring Trends Across Metrics:
#
# Tasks:
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
# {pearson correlation} with the Score for South Asian countries.
# 2. Create scatter plots with trendlines for these metrics against the Score.
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for
# South Asian countries.

# %%
#Choose two Metrics
metric_1 = 'Freedom to make life choices'
metric_2 = 'Generosity'
score_column = 'score'

# Calculate Pearson Correlation
correlation_metric_1 = southAsia_df[metric_1].corr(southAsia_df[score_column])
correlation_metric_2 = southAsia_df[metric_2].corr(southAsia_df[score_column])

print(f"Pearson Correlation between {metric_1} and Score: {correlation_metric_1:.2f}")
print(f"Pearson Correlation between {metric_2} and Score: {correlation_metric_2:.2f}")
# Out:
# Pearson Correlation between Freedom to make life choices and Score: 0.80
# Pearson Correlation between Generosity and Score: 0.87

# %%
#Create Scatter Plots with Trendlines
# Scatter Plot for Metric 1 vs Score
plt.figure(figsize=(10, 6))
sns.regplot(x=metric_1, y=score_column, data=southAsia_df, scatter_kws={'s': 100, 'color': 'seagreen'}, line_kws={'color': 'seagreen'})
plt.title(f"{metric_1} vs Score")
plt.xlabel(metric_1)
plt.ylabel('Score')
plt.show()

# %%
# Scatter Plot for Metric 2 vs Score
plt.figure(figsize=(10, 6))
sns.regplot(x=metric_2,y=score_column,data=southAsia_df,scatter_kws={'s': 100, 'color': 'purple'},line_kws={'color': 'purple'})
plt.title(f"Scatter Plot with Trendline: {metric_2} vs Score")
plt.xlabel(metric_2)
plt.ylabel('Score')
plt.show()

# %%
#Identify and Discuss Strongest and Weakest Relationships
if abs(correlation_metric_1) > abs(correlation_metric_2):
    strongest = "Metric 1"
    weakest = "Metric 2"
else:
    strongest = "Metric 2"
    weakest = "Metric 1"

print(f"The strongest relationship is between {strongest} and Score.")
print(f"The weakest relationship is between {weakest} and Score.")
# Out:
# The strongest relationship is between Metric 2 and Score.
# The weakest relationship is between Metric 1 and Score.

# %% [markdown]
# ## Task - 5 - Gap Analysis:
#
# Tasks:
#
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.
# 2. Rank the South Asian countries by this gap in both ascending and descending order.
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %%
#Add a new column 'GDP-Score Gap'
southAsia_df['GDP-Score Gap'] = southAsia_df['Log GDP per capita'] - southAsia_df['score']
southAsia_df['GDP-Score Gap']
# Out:
# 0   -4.193
# 1   -3.588
# 2   -2.888
# 3   -2.537
# 4   -2.764
# 5   -1.093
# Name: GDP-Score Gap, dtype: float64

# %%
#Rank South Asian countries by GDP-Score Gap
# Ascending order
gap_ascending = southAsia_df.sort_values(by='GDP-Score Gap', ascending=True)

# Descending order
gap_descending = southAsia_df.sort_values(by='GDP-Score Gap', ascending=False)

# Print the rankings
print("Top 3 Countries with Largest Positive Gaps (Descending):")
gap_descending[['Country name', 'Log GDP per capita', 'score', 'GDP-Score Gap']].head(3)
# Out:
# Top 3 Countries with Largest Positive Gaps (Descending):
#   Country name  Log GDP per capita  score  GDP-Score Gap
# 5  Afghanistan               0.628  1.721         -1.093
# 3    Sri Lanka               1.361  3.898         -2.537
# 4   Bangladesh               1.122  3.886         -2.764

# %%
#Visualize the Top 3 Positive and Negative Gaps
top_positive_gap = gap_descending.head(3)
top_negative_gap = gap_ascending.head(3)
# Combine Top 3 Positive and Top 3 Negative into one
combined_gap = pd.concat([top_positive_gap, top_negative_gap])
# Add a column to classify the gaps
combined_gap['Gap Type'] = ['Least Negative'] * 3 + ['Most Negative'] * 3

# Plot the bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='Country name', y='GDP-Score Gap', hue='Gap Type', data=combined_gap, palette='Set2')
plt.title('Top 3 Positive and Negative GDP-Score Gaps')
plt.xlabel('Country')
plt.ylabel('GDP-Score Gap')
plt.legend(title='Gap Type')
plt.show()

# %% [markdown]
# # **3.3 Problem - 3 - Comparative Analysis:**

# %% [markdown]
# ## **Task - 1 - Setup Task - Preparing the Middle Eastern Dataset:**
#
# Tasks:
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria","United Arab Emirates", "Yemen"]

# %%
#Middle east countries list
middle_east_countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
"Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
"United Arab Emirates", "Yemen"]

#Create Dataframe
middleEastCountries_df = df[df['Country name'].isin(middle_east_countries)]

# %% [markdown]
# 1. **Descriptive Statistics:**
#
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.
#
# • Which region has higher happiness Scores on average?

# %%
# Calculate mean and standard deviation for Score
south_asia_mean = southAsia_df['score'].mean()
south_asia_std = southAsia_df['score'].std()

middle_east_mean = middleEastCountries_df['score'].mean()
middle_east_std = middleEastCountries_df['score'].std()

print("Descriptive Statistics:")
print("\n")
print(f"South Asia:\nMean: {south_asia_mean:.2f},\nStandard Deviation: {south_asia_std:.2f}")
print("\n")
print(f"Middle East:\nMean: {middle_east_mean:.2f},\nStandard Deviation: {middle_east_std:.2f}")
print("\n")

#Check which region has higher happiness scores on average
if south_asia_mean > middle_east_mean:
    print("South Asia has higher happiness scores on average.")
else:
    print("Middle East has higher happiness scores on average.")
# Out:
# Descriptive Statistics:
#
#
# South Asia:
# Mean: 3.90,
# Standard Deviation: 1.18
#
#
# Middle East:
# Mean: 5.41,
# Standard Deviation: 1.57
#
#
# Middle East has higher happiness scores on average.

# %% [markdown]
# ## **2. Top and Bottom Performers:**
#
# • Identify the top 3 and bottom 3 countries in each re
#
# • Plot bar charts comparing these charts.

# %%
# Top 3 Performers in South Asia
top3_in_sa = southAsia_df.nlargest(3, 'score')
print("Top 3 Performers in South Asia:")
top3_in_sa
# Out:
# Top 3 Performers in South Asia:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
#
#    Perceptions of corruption  Dystopia + residual Happiness Category  \
# 0                      0.115                1.783             Medium
# 1                      0.074                1.907             Medium
# 2                      0.122                0.756             Medium
#
#    Composite Score  GDP-Score Gap
# 0           0.8159         -4.193
# 1           0.7039         -3.588
# ...

# %%
# Bottom 3 Performers in South Asia
bottom3_in_sa = southAsia_df.nsmallest(3, 'score')
print("Bottom 3 Performers in South Asia:")
bottom3_in_sa
# Out:
# Bottom 3 Performers in South Asia:
#   Country name  score  Log GDP per capita  Social support  \
# 5  Afghanistan  1.721               0.628           0.000
# 4   Bangladesh  3.886               1.122           0.249
# 3    Sri Lanka  3.898               1.361           1.179
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 5                    0.242                         0.000       0.091
# 4                    0.513                         0.775       0.140
# 3                    0.586                         0.583       0.144
#
#    Perceptions of corruption  Dystopia + residual Happiness Category  \
# 5                      0.088                0.672                Low
# 4                      0.167                0.919                Low
# 3                      0.031                0.014                Low
#
#    Composite Score  GDP-Score Gap
# 5           0.3238         -1.093
# 4           0.6774         -2.764
# ...

# %%
# Top 3 Performers in Middle East
top3_in_me = middleEastCountries_df.nlargest(3, 'score')
print("Top 3 Performers in Middle East:")
top3_in_me
# Out:
# Top 3 Performers in Middle East:
#             Country name  score  Log GDP per capita  Social support  \
# 4                 Israel  7.341               1.803           1.513
# 12                Kuwait  6.951               1.845           1.364
# 21  United Arab Emirates  6.733               1.983           1.164
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                     0.740                         0.641       0.153
# 12                    0.661                         0.827       0.200
# 21                    0.563                         0.815       0.209
#
#     Perceptions of corruption  Dystopia + residual Happiness Category
# 4                       0.193                2.298               High
# 12                      0.172                1.884               High
# 21                      0.258                1.741               High

# %%
#Bottom 3 performers in Middle East
bottom3_in_me = middleEastCountries_df.nsmallest(3, 'score')
print("Bottom 3 Performers in Middle East:")
bottom3_in_me
# Out:
# Bottom 3 Performers in Middle East:
#     Country name  score  Log GDP per capita  Social support  \
# 141      Lebanon  2.707               1.377           0.577
# 132        Yemen  3.561               0.671           1.281
# 124       Jordan  4.186               1.262           0.983
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 141                    0.556                         0.173       0.068
# 132                    0.293                         0.362       0.080
# 124                    0.594                         0.593       0.059
#
#      Perceptions of corruption  Dystopia + residual Happiness Category
# 141                      0.029               -0.073                Low
# 132                      0.113                0.760                Low
# 124                      0.189                0.504             Medium

# %%
 #pl
top3_in_sa['Group'] = 'Top 3'
bottom3_in_sa['Group'] = 'Bottom 3'

# Combine the data
combined_data = pd.concat([top3_in_sa, bottom3_in_sa])

plt.figure(figsize=(10, 6))
sns.barplot(x='score', y='Country name', data=combined_data, palette={'Top 3': 'seagreen', 'Bottom 3': 'gray'}, hue='Group')

plt.title('Top 3 and Bottom 3 Performers in South Asia')
plt.xlabel('Score')
plt.ylabel('Country')
plt.show()

# %%
 #p2
top3_in_me['Group'] = 'Top 3'
bottom3_in_me['Group'] = 'Bottom 3'
# Combine the data
combined_data = pd.concat([top3_in_me, bottom3_in_me])
# Combine Top 3 Positive and Top 3 Negative into one DataFrame
plt.figure(figsize=(10, 6))
sns.barplot(x='score', y='Country name', data=combined_data, palette={'Top 3': 'seagreen', 'Bottom 3': 'gray'}, hue='Group')

plt.title('Top 3 and Bottom 3 Performers in Middle East')
plt.xlabel('Score')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# ##3. Metric Comparisons:
#
# • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy between the regions using grouped bar charts.
#
# • Which metrics show the largest disparity between the two regions?

# %%
# Calculate the mean values of key metrics for South Asia and Middle East
metrics = ['Log GDP per capita', 'Social support', 'Healthy life expectancy']

# Calculate means for each metric in both regions
south_asia_means = southAsia_df[metrics].mean()
middle_east_means = middleEastCountries_df[metrics].mean()

# Combine the results into a single DataFrame for easy plotting
comparison = pd.DataFrame({'Metric': metrics,'South Asia': south_asia_means.values,'Middle East': middle_east_means.values})
# Melt the DataFrame for grouped bar plot
comparison_melted = comparison.melt(id_vars='Metric',
                                    value_vars=['South Asia', 'Middle East'],
                                    var_name='Region', value_name='Average Value')

# %%
# Plot grouped bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='Metric', y='Average Value', hue='Region', data=comparison_melted, palette='pastel')
plt.title("Comparison of Key Metrics Between South Asia and Middle East")
plt.ylabel("Average Value")
plt.xlabel("Metrics")
plt.legend(title="Region")
plt.show()

# Calculate disparities between the two regions
disparities = (middle_east_means - south_asia_means).abs()
largestDisparity_metric = disparities.idxmax()
largestDisparity_value = disparities.max()

print("Metric Disparities:")
print(disparities)

print(f"\nThe largest disparity is in '{largestDisparity_metric}' with a difference of {largestDisparity_value:.2f}.")
# Out:
# Metric Disparities:
# Log GDP per capita         0.444500
# Social support             0.540944
# Healthy life expectancy    0.133778
# dtype: float64
#
# The largest disparity is in 'Social support' with a difference of 0.54.

# %% [markdown]
# ##4. Happiness Disparity:
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
#
# • Which region has greater variability in happiness?

# %%
# Calculate range for each region
south_asia_range = southAsia_df['score'].max() - southAsia_df['score'].min()
middle_east_range = middleEastCountries_df['score'].max() - middleEastCountries_df['score'].min()

# Calculate coefficient of variation for each region
south_asia_cv = southAsia_df['score'].std() / southAsia_df['score'].mean()
middle_east_cv = middleEastCountries_df['score'].std() / middleEastCountries_df['score'].mean()

# Print results
print("Happiness Disparity Analysis:")
print(f"South Asia - Range: {south_asia_range:.2f}, CV: {south_asia_cv:.2f}")
print(f"Middle East - Range: {middle_east_range:.2f}, CV: {middle_east_cv:.2f}")

# check which region has greater variability
if south_asia_cv > middle_east_cv:
    print("\nSouth Asia has greater variability in happiness.")
elif middle_east_cv > south_asia_cv:
    print("\nMiddle East has greater variability in happiness.")
else:
    print("\nBoth regions have equal variability in happiness.")
# Out:
# Happiness Disparity Analysis:
# South Asia - Range: 3.44, CV: 0.30
# Middle East - Range: 4.63, CV: 0.29
#
# South Asia has greater variability in happiness.

# %% [markdown]
# ##5. Correlation Analysis:
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and
# Generosity within each region.
#
# • Create scatter plots to visualize and interpret the relationships.

# %%
metrics = ['Freedom to make life choices', 'Generosity']

# Calculate correlations for South Asia
southAsia_corr = southAsia_df[['score'] + metrics].corr()['score'].drop('score')

# Calculate correlations for Middle East
middleEast_corr = middleEastCountries_df[['score'] + metrics].corr()['score'].drop('score')

print("Correlation Analysis:")
print("South Asia:")
print(southAsia_corr)
print("\nMiddle East:")
print(middleEast_corr)
# Out:
# Correlation Analysis:
# South Asia:
# Freedom to make life choices    0.800519
# Generosity                      0.874512
# Name: score, dtype: float64
#
# Middle East:
# Freedom to make life choices    0.863220
# Generosity                      0.627524
# Name: score, dtype: float64

# %%
# Visualizing the relationships using scatter plots
#Visualization for South Asia
plt.figure(figsize=(12, 4))

for i, metric in enumerate(metrics):
    plt.subplot(1, len(metrics), i + 1)
    sns.scatterplot(x=metric, y='score', data=southAsia_df, color='blue', label='South Asia')
    plt.title(f"South Asia: Score vs {metric.capitalize()}")
    plt.xlabel(metric.capitalize())
    plt.ylabel('Score')

plt.tight_layout()
plt.show()

# %%
#Visualization for Middle East
plt.figure(figsize=(12, 4))

for i, metric in enumerate(metrics):
    plt.subplot(1, len(metrics), i + 1)
    sns.scatterplot(x=metric, y='score', data=middleEastCountries_df, color='green', label='Middle East')
    plt.title(f"Middle East: Score vs {metric.capitalize()}")
    plt.xlabel(metric.capitalize())
    plt.ylabel('Score')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##6. Outlier Detection:
# • Identify outlier countries in both regions based on Score and GDP per Capita.
#
#  • Plot these outliers and discuss their implications.

# %%
# Define the outlier detection logic
def find_outliers(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return data[(data[column] < lower_bound) | (data[column] > upper_bound)]

# Identify outliers for South Asia
southAsia_outliers_score = find_outliers(southAsia_df, 'score')
southAsia_outliers_gdp = find_outliers(southAsia_df, 'Log GDP per capita')

# Identify outliers for Middle East
middleEast_outliers_score = find_outliers(middleEastCountries_df, 'score')
middleEast_outliers_gdp = find_outliers(middleEastCountries_df, 'Log GDP per capita')

# %%
#Outliers in South Asia
southAsia_outliers = pd.concat([southAsia_outliers_score, southAsia_outliers_gdp]).drop_duplicates()
print("South Asia Outliers:")
southAsia_outliers
# Out:
# South Asia Outliers:
#   Country name  score  Log GDP per capita  Social support  \
# 5  Afghanistan  1.721               0.628             0.0
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 5                    0.242                           0.0       0.091
#
#    Perceptions of corruption  Dystopia + residual Happiness Category  \
# 5                      0.088                0.672                Low
#
#    Composite Score  GDP-Score Gap
# 5           0.3238         -1.093

# %%
#Outliers in Middle East
middleEast_outliers = pd.concat([middleEast_outliers_score, middleEast_outliers_gdp]).drop_duplicates()
print("\nMiddle East Outliers:")
print(middleEast_outliers)
# Out:
# Middle East Outliers:
# Empty DataFrame
# Columns: [Country name, score, Log GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption, Dystopia + residual, Happiness Category]
# Index: []

# %%
# Plot the outliers using scatter plots
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Log GDP per capita', y='score', data=southAsia_df, label='South Asia', color='blue')
sns.scatterplot(x='Log GDP per capita', y='score', data=middleEastCountries_df, label='Middle East', color='seagreen')
sns.scatterplot(x='Log GDP per capita', y='score', data=southAsia_outliers, label='South Asia Outliers', color='red', marker='o', s=50)
sns.scatterplot(x='Log GDP per capita', y='score', data=middleEast_outliers, label='Middle East Outliers', color='orange', marker='o', s=50)

plt.title('Outlier Detection Based on Score and GDP per Capita')
plt.xlabel('GDP per Capita')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# ##7. Visualization:
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
#
# • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
# Combine the data into one DataFrame for comparison
southAsia_df['Region'] = 'South Asia'
middleEastCountries_df.loc[:,'Region'] = 'Middle East'
combined_data = pd.concat([southAsia_df[['score', 'Region']], middleEastCountries_df[['Country name','score', 'Region']]])

# Create the boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Region', y='score', data=combined_data, palette='pastel',hue= 'Region',width=0.3)
plt.title('Boxplot Comparison of Score between South Asia and Middle East', fontsize=14)
plt.xlabel('Region', fontsize=12)
plt.ylabel('Score', fontsize=12)

plt.show()
